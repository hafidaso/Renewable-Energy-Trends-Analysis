# %% [markdown]
# # 🌍 Renewable Energy Trends Analysis: Extended Insights & Regression Summary 🔋
# ### The Data Analyst Wizard
#
# ## 📖 Background
# The race to net-zero emissions is on! As the world battles climate change and rising energy demands, renewable energy is taking center stage. Solar, wind, and hydro are revolutionizing the way we power our lives. Some countries are leading the charge, while others are falling behind. But which nations are making the biggest impact? What’s driving their success? And what lessons can we learn to accelerate the green energy transition?
#
# As a data analyst at NextEra Energy, one of the world’s leading renewable energy providers, your mission is to dive deep into global trends and uncover the story behind the surge in clean energy. Using real-world data, you'll explore how economic, demographic, and environmental factors (like GDP, population, carbon emissions, and policy influence) shape energy production around the world.
#
# So dig into the data, reveal the story behind the numbers, and create stunning visualizations that spark action! ⚡🌱

# %% [markdown]
# ## 💾 The data
# Your team has gathered a **global renewable energy dataset** covering energy production, investments, policies, and economic factors shaping renewable adoption worldwide:
#
# ## 🌍 Basic Identifiers
# - **`Country`** – Country name
# - **`Year`** – Calendar year (YYYY)
# - **`Energy Type`** – Type of renewable energy (e.g., Solar, Wind)
#
# #### ⚡ Energy Metrics
# - **`Production (GWh)`** – Renewable energy produced (Gigawatt-hours)
# - **`Installed Capacity (MW)`** – Installed renewable capacity (Megawatts)
# - **`Investments (USD)`** – Total investment in renewables (US Dollars)
# - **`Energy Consumption (GWh)`** – Total national energy use
# - **`Energy Storage Capacity (MWh)`** – Capacity of energy storage systems
# - **`Grid Integration Capability (Index)`** – Scale of 0–1; ability to handle renewables in grid
# - **`Electricity Prices (USD/kWh)`** – Average cost of electricity
# - **`Energy Subsidies (USD)`** – Government subsidies for energy sector
# - **`Proportion of Energy from Renewables (%)`** – Share of renewables in total energy mix
#
# #### 🧠 Innovation & Tech
# - **`R&D Expenditure (USD)`** – R&D spending on renewables
# - **`Renewable Energy Patents`** – Number of patents filed
# - **`Innovation Index (Index)`** – Global innovation score (0–100)
#
# #### 💰 Economy & Policy
# - **`GDP (USD)`** – Gross domestic product
# - **`Population`** – Total population
# - **`Government Policies`** – Number of policies supporting renewables
# - **`Renewable Energy Targets`** – Whether national targets are in place (1 = Yes, 0 = No)
# - **`Public-Private Partnerships in Energy`** – Number of active collaborations
# - **`Energy Market Liberalization (Index)`** – Scale of 0–1
#
# #### 🧑‍🤝‍🧑 Social & Governance
# - **`Ease of Doing Business (Score)`** – World Bank index (0–100)
# - **`Regulatory Quality`** – Governance score (-2.5 to 2.5)
# - **`Political Stability`** – Governance score (-2.5 to 2.5)
# - **`Control of Corruption`** – Governance score (-2.5 to 2.5)
#
# #### 🌿 Environment & Resources
# - **`CO2 Emissions (MtCO2)`** – Emissions in million metric tons
# - **`Average Annual Temperature (°C)`** – Country’s avg. temp
# - **`Solar Irradiance (kWh/m²/day)`** – Solar energy availability
# - **`Wind Speed (m/s)`** – Average wind speed
# - **`Hydro Potential (Index)`** – Relative hydropower capability (0–1)
# - **`Biomass Availability (Tons/year)`** – Total available biomass

# %% [markdown]
# ## 💪 Challenge
#
# As a data analyst at NextEra Energy, your mission is to explore a rich, multi-dimensional dataset and uncover powerful insights about global renewable energy trends.
#
# Your submission should focus on:
#
# 1. **🌍 Exploratory Insights:**
#    Alongside your model, include analysis addressing key trends:
#    - Which regions are investing the most efficiently in renewables?
#    - How do economic, environmental, and policy factors relate to production levels?
#
# 2. **📊 Visual Storytelling:**
#    Create at least one compelling visualization to showcase a key insight about global renewable energy trends.
#
# 🔎 Your analysis will uncover trends, spotlight key drivers, and guide smarter global energy decisions. Policymakers, investors, and sustainability leaders are hungry for clarity. Your insights could influence real-world energy strategies and help accelerate the path to a more sustainable future.

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('/Users/ymadigital/Downloads/workspace 3/data/Training_set_augmented.csv')
train_df.head()
# Out:
#      Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0     Canada  2012       Hydro      99925.061260             26824.443710
# 1     Brazil  2016       Solar      89553.347010              5021.215089
# 2     France  2002       Hydro      18200.049220             33611.581480
# 3     Brazil  2014       Solar      82593.101462             30016.235570
# 4  Australia  2015     Biomass      15042.899900             12148.925160
#
#    Investments (USD)  Energy Consumption  Energy Storage Capacity  \
# 0       3.439820e+09       743320.095400               523.227159
# 1       2.306911e+08       755329.781300               595.364642
# 2       7.337585e+09       302879.870000               423.230209
# 3       4.158375e+09       273895.437151                35.006229
# 4       9.426154e+09       465093.510500               874.578417
#
#    Grid Integration Capability  Electricity Prices  ...  \
# 0                     0.757701            0.135676  ...
# ...

# %%
print('Training Data Info:')
train_df.info()
print('\nTraining Data Description:')
print(train_df.describe(include='all'))
# Out:
# Training Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Country                                2400 non-null   object
#  1   Year                                   2400 non-null   int64
#  2   Energy Type                            2400 non-null   object
#  3   Production (GWh)                       2400 non-null   float64
#  4   Installed Capacity (MW)                2400 non-null   float64
#  5   Investments (USD)                      2400 non-null   float64
#  6   Energy Consumption                     2400 non-null   float64
#  7   Energy Storage Capacity                2400 non-null   float64
#  8   Grid Integration Capability            2400 non-null   float64
#  9   Electricity Prices                     2400 non-null   float64
# ...

# %%
print(train_df.isnull().sum())
# Out:
# Country                                  0
# Year                                     0
# Energy Type                              0
# Production (GWh)                         0
# Installed Capacity (MW)                  0
# Investments (USD)                        0
# Energy Consumption                       0
# Energy Storage Capacity                  0
# Grid Integration Capability              0
# Electricity Prices                       0
# Energy Subsidies                         0
# Proportion of Energy from Renewables     0
# R&D Expenditure                          0
# Renewable Energy Patents                 0
# Innovation Index                         0
# GDP                                      0
# Population                               0
# Government Policies                      0
# Renewable Energy Targets                 0
# Public-Private Partnerships in Energy    0
# Energy Market Liberalization             0
# Ease of Doing Business                   0
# ...

# %% [markdown]
# # Analyze key trends: Production over time by Energy Type and Country

# %%
from tabulate import tabulate


try:
    # Grouping and summing production by year and energy type
    production_by_year_energy = train_df.pivot_table(
        values='Production (GWh)',
        index='Year',
        columns='Energy Type',
        aggfunc='sum'
    )
    
    # Grouping and summing production by year and country
    production_by_year_country = train_df.pivot_table(
        values='Production (GWh)',
        index='Year',
        columns='Country',
        aggfunc='sum'
    )
    
    # Displaying the results
    print('Production (GWh) by Year and Energy Type:\n', production_by_year_energy.to_markdown())
    print('\nProduction (GWh) by Year and Country:\n', production_by_year_country.to_markdown())

except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# Production (GWh) by Year and Energy Type:
#  |   Year |          Biomass |       Geothermal |            Hydro |            Solar |             Wind |
# |-------:|-----------------:|-----------------:|-----------------:|-----------------:|-----------------:|
# |   2000 | 881478           | 805713           | 747353           | 840093           |      1.14773e+06 |
# |   2001 |      1.32821e+06 | 643933           |      1.17104e+06 | 825465           |      1.26334e+06 |
# |   2002 | 788499           | 807203           |      1.14201e+06 |      1.46861e+06 |      1.08255e+06 |
# |   2003 | 919556           | 758806           | 643752           |      1.16316e+06 | 977021           |
# |   2004 | 830042           |      1.16534e+06 | 817490           |      1.0779e+06  |      1.17471e+06 |
# |   2005 | 905054           |      1.0474e+06  | 796373           | 730363           | 779333           |
# ...

# %% [markdown]
# ### Production by Energy Type Over Time
#
# Our analysis of **Production (GWh) by Year and Energy Type** reveals fluctuating but generally increasing trends across different renewable energy sources. While there isn't a consistent year-on-year increase for all types, the overall capacity and output of renewable energy have grown significantly over the years. Hydro and Wind energy types show substantial production, with Solar and Biomass also contributing significantly. Geothermal production also shows a steady contribution.

# %% [markdown]
# ### Production by Country Over Time ###
#
# The **Production (GWh) by Year and Country** data indicates varying levels of renewable energy production across different nations. Some countries consistently show high production, while others have more sporadic contributions. This suggests diverse approaches to renewable energy adoption and development, influenced by factors such as natural resources, policy, and economic conditions.

# %%
try:
    # Calculate investment efficiency
    train_df['Investment Efficiency'] = train_df['Production (GWh)'] / train_df['Investments (USD)']
    
    # Calculate average investment efficiency per country
    investment_efficiency_by_country = (
        train_df.groupby('Country')['Investment Efficiency']
        .mean()
        .sort_values(ascending=False)
    )
    
    print(
        'Average Investment Efficiency by Country (Production GWh per USD Investment):\n',
        investment_efficiency_by_country.to_markdown()
    )
    
    # Calculate correlation of numerical features with Production (GWh)
    numerical_cols = train_df.select_dtypes(include=['float64', 'int64']).columns
    numerical_cols = numerical_cols.drop(['ID', 'Year'], errors='ignore')
    
    production_correlation = train_df[numerical_cols].corr()['Production (GWh)'].sort_values(ascending=False)
    
    print('\nCorrelation of Features with Production (GWh):\n', production_correlation.to_markdown())

except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# Average Investment Efficiency by Country (Production GWh per USD Investment):
#  | Country   |   Investment Efficiency |
# |:----------|------------------------:|
# | China     |             9.64268e-05 |
# | Japan     |             6.96862e-05 |
# | India     |             6.70683e-05 |
# | Germany   |             4.27094e-05 |
# | Russia    |             3.63214e-05 |
# | France    |             2.84496e-05 |
# | Canada    |             2.76706e-05 |
# | UK        |             2.3249e-05  |
# | Australia |             2.31471e-05 |
# | Brazil    |             2.18286e-05 |
# | USA       |             2.17492e-05 |
#
# Correlation of Features with Production (GWh):
#  |                                       |   Production (GWh) |
# |:--------------------------------------|-------------------:|
# | Production (GWh)                      |         1          |
# | Investment Efficiency                 |         0.0798294  |
# ...

# %% [markdown]
# ### Regions Investing Most Efficiently in Renewables
#
# China, Japan, and India appear to be the most efficient in terms of GWh produced per USD invested, indicating that their investments are yielding higher energy outputs compared to other nations in the dataset. This could be attributed to factors such as lower labor costs, efficient project management, or specific policy incentives that maximize return on investment in renewable energy infrastructure.

# %% [markdown]
# **Positive Correlations:**
#
# • **Investment Efficiency, Average Annual Temperature, Public-Private Partnerships in Energy, Renewable Energy Targets, Solar Irradiance, Electricity Prices, Proportion of Energy from Renewables, Wind Speed, Hydro Potential, Innovation Index, and Energy Market Liberalization** show a positive correlation with **Production (GWh)**. This suggests that higher values in these factors are generally associated with increased renewable energy production. Notably, **Investment Efficiency** has the strongest positive correlation, reinforcing the importance of efficient investment strategies.

# %% [markdown]
# **Negative Correlations:**
#
# • **Factors such as CO2 Emissions, Energy Consumption, Renewable Energy Patents, Political Stability, Investments (USD), Population, Control of Corruption, Regulatory Quality, Ease of Doing Business, Biomass Availability, Energy Storage Capacity, Energy Subsidies, Grid Integration Capability, R&D Expenditure, Installed Capacity (MW), GDP, and Government Policies** show a negative correlation with Production (GWh). While some of these might seem counter-intuitive (e.g., Investments (USD) having a negative correlation), it's important to remember that correlation does not imply causation. Further in-depth analysis would be required to understand the underlying dynamics. For instance, a negative correlation with Investments (USD) might indicate that countries with already high production levels require less new investment to maintain or slightly increase output, or that initial large investments have already yielded their primary returns.

# %%
try:
    # Calculate investment efficiency
    train_df['Investment Efficiency'] = train_df['Production (GWh)'] / train_df['Investments (USD)']
    
    # Average investment efficiency per country
    investment_efficiency_by_country = (train_df.groupby('Country')['Investment Efficiency'].mean().sort_values(ascending=False))
    
    # Plot investment efficiency by country
    plt.figure(figsize=(12, 7))
    sns.barplot(x=investment_efficiency_by_country.index, y=investment_efficiency_by_country.values, palette='viridis')
    plt.title('Average Investment Efficiency by Country (GWh/USD)')
    plt.xlabel('Country')
    plt.ylabel('Efficiency (GWh/USD)')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# /var/folders/1s/8_yq4qfn4wg43t727cpmhgb40000gn/T/ipykernel_10433/1537042002.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=investment_efficiency_by_country.index, y=investment_efficiency_by_country.values, palette='viridis')

# %%
# Select only numeric variables
numeric_df = train_df.select_dtypes(include=[np.number])

# Correlation matrix
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(14,10))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
# Define features and target
X = train_df.drop(columns=['Production (GWh)'])
y = train_df['Production (GWh)']

# One-hot encode categorical variables
X = pd.get_dummies(X, drop_first=True)

# Convert all columns to float (ensures numeric dtype)
X = X.astype(float)
y = y.astype(float)

# Add constant term
X = sm.add_constant(X)

# Fit model
model = sm.OLS(y, X).fit()

# summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Production (GWh)   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.976
# Date:                Thu, 19 Jun 2025   Prob (F-statistic):            0.00516
# Time:                        14:24:23   Log-Likelihood:                -28001.
# No. Observations:                2400   AIC:                         5.605e+04
# Df Residuals:                    2378   BIC:                         5.617e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# We applied Multiple Linear Regression (OLS) to better understand the multivariate influence on renewable energy production.
#
# **Key Findings:**
# R-squared: 0.017 — the model explains only ~1.7% of the variance in Production (GWh), suggesting a weak linear fit.
#
# **Significant Predictor:**
#
# Year (p < 0.001): Positive and significant, confirming temporal growth in production.
#
# Average Annual Temperature (p = 0.003): Positively associated with production, possibly due to solar potential.
#
# Investment Efficiency (p ≈ 0.068): Marginally significant, supporting its correlation-based importance.
#
# Non-significant Factors: Most economic, policy, and population-based factors have high p-values (>0.1), indicating low individual significance in this linear model.
#
# **Model Limitations:**
# The condition number is high (3.43e+17), suggesting multicollinearity among predictors, which can distort coefficient estimates.
#
# Despite low R², the model is useful for hypothesis testing and identifying non-linear or interaction patterns for further study.

# %%
# Interaction between Investment and Political_Stability
train_df['Invest_PS'] = train_df['Investments (USD)'] * train_df['Political Stability']

X_inter = train_df[['Investments (USD)', 'Political Stability', 'Invest_PS']]
X_inter = sm.add_constant(X_inter)
y = train_df['Production (GWh)']

model_inter = sm.OLS(y, X_inter).fit()
print(model_inter.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Production (GWh)   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3491
# Date:                Thu, 19 Jun 2025   Prob (F-statistic):              0.790
# Time:                        14:27:32   Log-Likelihood:                -28021.
# No. Observations:                2400   AIC:                         5.605e+04
# Df Residuals:                    2396   BIC:                         5.607e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                5.054e+04   2262.190     22.343      0.000    4.61e+04     5.5e+04
# ...

# %% [markdown]
# **Interactions and Multicollinearity Consideration**
# An exploratory interaction term between Investments and Political Stability was tested but did not yield statistical significance (p = 0.323). However, the model's weak performance may also stem from:
#
# * Highly correlated predictors
# * Unobserved latent variables (e.g., technological readiness, workforce skills)
# * Time-lag effects not captured by static regression

# %% [markdown]
# **✅ Conclusions & Policy Recommendations**
#
# * Renewable energy production is increasing over time, supported by rising investment efficiency and enabling policy environments.
# * Investment Efficiency, climate suitability, and public-private partnerships are more influential than raw investment totals.
# * Negative correlations with economic and policy indicators suggest a need for targeted policy reforms, especially in countries where high spending does not translate into high output.
# * Given the low explanatory power of the linear model, non-linear modeling approaches (e.g., Random Forests, Time Series, Panel Data Models) are recommended for future analysis.
